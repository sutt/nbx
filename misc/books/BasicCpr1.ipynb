# %% [markdown]
# ### Demonstrate Answer-Receive: Reload + Goto
#
# `reload_nb()` will allow us to simulate an *answer-receive* action on the front end. Specific requirements:
#  - save notebook (TODO)
#  - reload notebook
#  - scroll to previous cell
#  - select previous cell
#  - flash previous cell
#
# These are all actions we need to simulate a student receiving answers in a seemless, browser driven way.

# %%
import sys
sys.path.append('../../')
# %reload_ext autoreload
# %autoreload 2
from cpr import cpr

# %% [markdown]
# ### Demonstration Simple
# *Run the cell below* - notebook will refresh and come back to this cell

# %%
cpr.reload_nb()

# %% [markdown]
# ### Demonstrate with flags
# *Set boolen options below*

# %%
reload_nb(  b_save=False,  # save before
            b_scroll=True, # scroll into view (if nec)
            b_select=True, # bring selection to that cell
            b_flash=True,  # flash green
            b_log=True,    # output to dev console
            debug=False,   # outputs python-generated js script to debug-js.js
         )

# %% [markdown]
# ### Demonstrate Save

# %%
# add some snippet here

# %%
# now run and see the snippet is still there

# %% [markdown]
# ### Demonstrate Scroll Behavior
# We'll add some vertical whitepace here
# ```
#                            .-""-.
#                           (___/\ \
#         ,                 (|^ ^ ) )
#        /(                _)_\=_/  (
#  ,..__/ `\          ____(_/_ ` \   )
#   `\    _/        _/---._/(_)_  `\ (
# jgs '--\ `-.__..-'    /.    (_), |  )
#         `._        ___\_____.'_| |__/
#            `~----"`   `-.........'
# ```
# This will force us the scroll to the cell below when it is run.

# %%
cpr.reload_nb()
