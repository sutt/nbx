# %% [markdown]
# ### Investigating Particular API constants and methods with jupyter-type packages
#
# mostly useful to understand the way the project is structured.
#
# note: these paths depend on which python environment are enabled. Below they are run with conda `root` environment active

# %%
import notebook
import IPython

# %%
notebook.DEFAULT_STATIC_FILES_PATH
# Out:
# 'C:\\Users\\wsutt\\Anaconda3\\lib\\site-packages\\notebook\\static'

# %%
notebook.nbextensions.ENV_JUPYTER_PATH
# Out:
# ['C:\\Users\\wsutt\\Anaconda3\\share\\jupyter']

# %%
notebook.nbextensions.NBCONFIG_SECTIONS
# Out:
# ['common', 'notebook', 'tree', 'edit', 'terminal']

# %%
notebook.DEFAULT_TEMPLATE_PATH_LIST
# Out:
# ['C:\\Users\\wsutt\\Anaconda3\\lib\\site-packages\\notebook',
#  'C:\\Users\\wsutt\\Anaconda3\\lib\\site-packages\\notebook\\templates']

# %%
# %connect_info
# Out:
# {
#   "shell_port": 50030,
#   "iopub_port": 50031,
#   "stdin_port": 50032,
#   "control_port": 50033,
#   "hb_port": 50034,
#   "ip": "127.0.0.1",
#   "key": "fe6d9f0c-100c7fc0da65c0b7aef3cfec",
#   "transport": "tcp",
#   "signature_scheme": "hmac-sha256",
#   "kernel_name": ""
# }
#
# Paste the above JSON into a file, and connect with:
#     $> jupyter <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> jupyter <app> --existing kernel-f9282c89-aba9-46f9-ad53-abdbecd4b9bb.json
# or even just:
#     $> jupyter <app> --existing
# if this is the most recent Jupyter kernel you have started.

# %%
#shows aardvark in help pop-up
IPython.core.payloadpage.page('aardvark')

# %%
q = IPython.core.page.get_ipython()

# %%
q.configurables

# %%
# looks like this gives us the json representation of the notebook
ret = IPython.core.page.page_file('HelloCpr.ipynb')
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "### HelloCpr - basics of importing the module and executing it's methods"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 1,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "import sys\n",
#     "sys.path.append('../../')\n",
#     "%reload_ext autoreload\n",
#     "%autoreload 2\n",
#     "import cpr.cpr as cpr"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 2,
#    "metadata": {},
#    "outputs": [
#     {
#      "name": "stdout",
#      "output_type": "stream",
#      "text": [
#       "hello world\n"
#      ]
#     }
#    ],
#    "source": [
#     "cpr.hello()"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 31,
#    "metadata": {},
#    "outputs": [
#     {
#      "name": "stdout",
#      "output_type": "stream",
#      "text": [
#       "new\n"
#      ]
#     }
#    ],
#    "source": [
# ...
