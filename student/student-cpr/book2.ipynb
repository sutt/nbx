# %% [markdown]
# ### Demo: full functionality
# We'll display:
#  - teacher/
#    - `merge.give_answer()`
#    - `gitcomm.push_answer()`
#  - student/
#   - `gitcomm.pull_answer()`
#   - `merge.get_answer()`
#   - `cpr.realod_nb()`

# %%
import sys
sys.path.append('../../')
# %reload_ext autoreload
# %autoreload 2
from cpr import cpr
from cpr import merge
from cpr import gitcomm

# %%
gitcomm.pull_answer(b_log=True)
# Out:
# time for check_output: 0.45
# ======================Output===========================
#
#  ------------------------------------------------------
# git pull local master
#  ------------------------------------------------------
# Merge made by the 'recursive' strategy.
#  .cpr/cells.json | 1 +
#  1 file changed, 1 insertion(+)
#  create mode 100644 .cpr/cells.json

# %%
# !cat .cpr/cells.json
# Out:
# {"cells": [{"cell_type": "code", "execution_count": 42, "metadata": {}, "outputs": [{"data": {"text/plain": ["'ab'"]}, "execution_count": 42, "metadata": {}, "output_type": "execute_result"}], "source": ["#answer cell\n", "q = ['a', 'b']\n", "qq = ''.join(q)\n", "qq"]}]}

# %%
#answer cell
q = ['a', 'b']
qq = ''.join(q)
qq
# Out:
# 'ab'

# %%
#whitespace

# %%
#answer cell
q = ['a', 'b']
qq = ''.join(q)
qq
# Out:
# 'ab'

# %%
#whitespace

# %%
#answer cell
q = ['a', 'b']
qq = ''.join(q)
qq
# Out:
# 'ab'

# %%
merge.get_answer('book2.ipynb', b_replace=False)
cpr.reload_nb()

# %%
# whitespace
